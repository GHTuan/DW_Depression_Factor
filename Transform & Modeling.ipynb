# %% [markdown]
# # Library and other import

# %%
from controller import fetchAll

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,f1_score,recall_score,precision_score

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping # Import EarlyStopping
from sklearn.utils import class_weight as sk_class_weight # Để tránh nhầm tên

# %% [markdown]
# # Load Data

# %%
data = fetchAll()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             2556 non-null   int64
#  1   age                            2556 non-null   int64
#  2   depression                     2556 non-null   bool
#  3   dietary_habits                 2556 non-null   object
#  4   family_mental_illness_history  2556 non-null   bool
#  5   financial_stress               2556 non-null   int64
#  6   gender                         2556 non-null   object
#  7   sleep_duration                 2556 non-null   object
#  8   suicidal_thoughts              2556 non-null   bool
#  9   work_hours                     2556 non-null   int64
#  10  work_pressure                  2556 non-null   int64
#  11  work_satisfaction              2556 non-null   int64
#  12  from_source                    2556 non-null   object
# dtypes: bool(3), int64(6), object(4)
# memory usage: 207.3+ KB

# %% [markdown]
# # Transform

# %% [markdown]
# Category Data

# %%
data = pd.get_dummies(data, columns=['dietary_habits', 'gender', 'sleep_duration','from_source'], drop_first=False)
data.columns = data.columns.str.replace(' ', '_')

# %% [markdown]
# Numerical Data

# %%
scaler = StandardScaler()
numerical_cols = ['age','financial_stress','work_hours','work_pressure','work_satisfaction']

data[numerical_cols] = scaler.fit_transform(data[numerical_cols])

data.drop(['id'], axis=1, inplace=True)

# %%
data.head()
# Out:
#         age  depression  family_mental_illness_history  financial_stress  \
# 0 -0.900869       False                           True         -0.684473
# 1 -0.900869       False                           True         -1.391062
# 2 -1.145604        True                          False          0.728704
# 3 -1.308760       False                           True         -0.684473
# 4 -0.656135       False                           True         -0.684473
#
#    suicidal_thoughts  work_hours  work_pressure  work_satisfaction  \
# 0               True    0.789215      -0.721512           0.690376
# 1               True    0.258853       0.695457           1.399907
# 2               True    1.054397      -1.429997          -0.019154
# 3               True    0.258853      -1.429997           0.690376
# 4               True   -0.536691      -1.429997           1.399907
#
#    dietary_habits_Healthy  dietary_habits_Moderate  dietary_habits_Unhealthy  \
# 0                   False                     True                     False
# 1                    True                    False                     False
# 2                   False                    False                      True
# 3                   False                    False                      True
# 4                    True                    False                     False
#
#    gender_Female  gender_Male  sleep_duration_5-6_hours  \
# 0          False         True                     False
# 1          False         True                      True
# 2          False         True                      True
# 3          False         True                     False
# 4           True        False                     False
#
#    sleep_duration_7-8_hours  sleep_duration_Less_than_5_hours  \
# 0                      True                             False
# 1                     False                             False
# 2                     False                             False
# 3                     False                             False
# 4                     False                             False
#
#    sleep_duration_More_than_8_hours  from_source_Professional  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                              True                     False
# 4                              True                     False
#
#    from_source_Student
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True

# %% [markdown]
# # Model

# %%
X = data.drop('depression', axis=1)
y= data['depression']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ## Utils

# %%
def getResult(y_test,y_pred):
  accuracy = accuracy_score(y_test, y_pred)
  precision = precision_score(y_test, y_pred)
  recall = recall_score(y_test, y_pred)
  f1 = f1_score(y_test, y_pred)
  print('Accuracy:',accuracy)
  print('Precision:',precision)
  print('Recall:', recall)
  print('F1 score:',f1)
  print('Confusion matrix:')
  print(confusion_matrix(y_test, y_pred))
  return [accuracy,precision,recall,f1]

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(random_state=0, class_weight='balanced', max_iter=1000)
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
lr_result = ['Logistic Regression'] + getResult(y_test,y_pred)
# Out:
# Accuracy: 0.9778357235984355
# Precision: 0.8924050632911392
# Recall: 1.0
# F1 score: 0.9431438127090301
# Confusion matrix:
# [[609  17]
#  [  0 141]]

# %% [markdown]
# ## Naive Bayes

# %%
NB = GaussianNB()
NB.fit(X_train, y_train)
y_pred = NB.predict(X_test)

# %%
nb_result = ['Naive Bayes'] + getResult(y_test,y_pred)
# Out:
# Accuracy: 0.81877444589309
# Precision: 0.5061728395061729
# Recall: 0.5815602836879432
# F1 score: 0.5412541254125413
# Confusion matrix:
# [[546  80]
#  [ 59  82]]

# %% [markdown]
# ## Decision Tree

# %%
dstree = DecisionTreeClassifier(criterion='gini', max_depth=10, min_samples_split=2, random_state=42, class_weight='balanced')
dstree.fit(X_train, y_train)
y_pred = dstree.predict(X_test)

# %%
dstree_result = ['Decision Tree'] + getResult(y_test,y_pred)
# Out:
# Accuracy: 0.9126466753585397
# Precision: 0.7890625
# Recall: 0.7163120567375887
# F1 score: 0.7509293680297398
# Confusion matrix:
# [[599  27]
#  [ 40 101]]

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(criterion='gini', max_depth=10, min_samples_split=2, n_estimators = 10, random_state=42,  class_weight='balanced')
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
rf_result = ['Random Forest'] + getResult(y_test,y_pred)
# Out:
# Accuracy: 0.9113428943937418
# Precision: 0.8924731182795699
# Recall: 0.5886524822695035
# F1 score: 0.7094017094017094
# Confusion matrix:
# [[616  10]
#  [ 58  83]]

# %% [markdown]
# ## XGBoost

# %%
neg_count = np.sum(y_train == 0)
pos_count = np.sum(y_train == 1)
if pos_count > 0:
    scale_pos_weight_value = neg_count / pos_count
    print(f"Calculated scale_pos_weight: {scale_pos_weight_value:.2f}")
else:
    scale_pos_weight_value = 1 # Giá trị mặc định nếu không có lớp dương
    print("Warning: No positive samples found in y_train. Setting scale_pos_weight to 1.")
# Out:
# Calculated scale_pos_weight: 4.70

# %%
xgb = XGBClassifier(random_state=42,
                    scale_pos_weight=scale_pos_weight_value,
                    n_estimators=100, # Có thể tăng/giảm để thử nghiệm
                    max_depth=5,      # Có thể thay đổi
                    # use_label_encoder=False,
                    eval_metric='logloss')
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

# %%
xgb_result = ['XGBoost'] + getResult(y_test, y_pred_xgb)
# Out:
# Accuracy: 0.9621903520208605
# Precision: 0.8943661971830986
# Recall: 0.900709219858156
# F1 score: 0.8975265017667845
# Confusion matrix:
# [[611  15]
#  [ 14 127]]

# %% [markdown]
# ## MLP

# %%
numerical_cols_mlp = ['age','financial_stress','work_hours','work_pressure','work_satisfaction'] # Kiểm tra lại
categorical_cols_mlp = [col for col in data.columns if col not in numerical_cols_mlp and col != 'depression']

data_mlp = data.copy()

# Tách X và y cho MLP
X_mlp_df = data_mlp.drop('depression', axis=1) # Giữ dạng DataFrame
y_mlp = data_mlp['depression']

# Tách train/test cho MLP (sử dụng cùng random_state và stratify)
X_train_mlp_df, X_test_mlp_df, y_train_mlp, y_test_mlp = train_test_split(X_mlp_df, y_mlp, test_size=0.30, random_state=42, stratify=y_mlp)

# Định dạng lại X thành danh sách các input cho Keras
X_train_list = [X_train_mlp_df[numerical_cols_mlp].values]
X_test_list = [X_test_mlp_df[numerical_cols_mlp].values]
for col in categorical_cols_mlp:
    X_train_list.append(X_train_mlp_df[col].values)
    X_test_list.append(X_test_mlp_df[col].values)

# Tính class_weight cho Keras
class_weights_mlp = sk_class_weight.compute_class_weight(
    'balanced', classes=np.unique(y_train_mlp), y=y_train_mlp
)
class_weight_dict_mlp = dict(enumerate(class_weights_mlp))
print(f"Calculated class weights for Keras: {class_weight_dict_mlp}")

# Xây dựng mô hình MLP (Giữ kiến trúc cơ bản, thêm Dropout)
input_layers = []
embedding_layers = []
input_numeric = layers.Input(shape=(len(numerical_cols_mlp),), name='input_numeric')
input_layers.append(input_numeric)
embedding_layers.append(input_numeric)

for col in categorical_cols_mlp:
    num_unique_values = data_mlp[col].nunique() + 1
    embedding_dim = min(50, int(num_unique_values / 2))
    input_cat = layers.Input(shape=(1,), name=f'input_{col}')
    input_layers.append(input_cat)
    embedding = layers.Embedding(input_dim=num_unique_values, output_dim=embedding_dim, name=f'embedding_{col}')(input_cat)
    embedding = layers.Flatten(name=f'flatten_{col}')(embedding)
    embedding_layers.append(embedding)

merged_inputs = layers.concatenate(embedding_layers, name='concatenate_embeddings')
dense1 = layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001), name='dense_1')(merged_inputs) # Thêm L2 reg
bn1 = layers.BatchNormalization(name='batchnorm_1')(dense1)
dropout1 = layers.Dropout(0.4, name='dropout_1')(bn1) # Tăng nhẹ Dropout
dense2 = layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001), name='dense_2')(dropout1) # Thêm L2 reg
bn2 = layers.BatchNormalization(name='batchnorm_2')(dense2)
dropout2 = layers.Dropout(0.4, name='dropout_2')(bn2) # Tăng nhẹ Dropout
output_layer = layers.Dense(1, activation='sigmoid', name='output')(dropout2)
model_mlp = keras.Model(inputs=input_layers, outputs=output_layer)
model_mlp.summary()

# Biên dịch mô hình
model_mlp.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), # Giữ Adam, lr mặc định
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')])

# ----- BỔ SUNG: Early Stopping -----
early_stopping = EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0,
)
# ----------------------------------

# Huấn luyện mô hình với Early Stopping
EPOCHS = 1000 # Tăng số epochs vì có EarlyStopping
BATCH_SIZE = 64
history = model_mlp.fit(
    X_train_list,
    y_train_mlp,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.2,
    class_weight=class_weight_dict_mlp,
    callbacks=[early_stopping], # Thêm callback EarlyStopping
    verbose=1
)
# Out:
# Calculated class weights for Keras: {0: np.float64(0.6080897348742352), 1: np.float64(2.8128930817610063)}
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_family_menta… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_suicidal_tho… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_dietary_habi… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_dietary_habi… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_dietary_habi… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_gender_Female │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_gender_Male   │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_sleep_durati… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_sleep_durati… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_sleep_durati… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_sleep_durati… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_from_source_… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_from_source_… │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_family_m… │ (None, 1, 1)      │          3 │ input_family_men… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_suicidal… │ (None, 1, 1)      │          3 │ input_suicidal_t… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_dietary_… │ (None, 1, 1)      │          3 │ input_dietary_ha… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_dietary_… │ (None, 1, 1)      │          3 │ input_dietary_ha… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_dietary_… │ (None, 1, 1)      │          3 │ input_dietary_ha… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_gender_F… │ (None, 1, 1)      │          3 │ input_gender_Fem… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_gender_M… │ (None, 1, 1)      │          3 │ input_gender_Mal… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_sleep_du… │ (None, 1, 1)      │          3 │ input_sleep_dura… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_sleep_du… │ (None, 1, 1)      │          3 │ input_sleep_dura… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_sleep_du… │ (None, 1, 1)      │          3 │ input_sleep_dura… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_sleep_du… │ (None, 1, 1)      │          3 │ input_sleep_dura… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_from_sou… │ (None, 1, 1)      │          3 │ input_from_sourc… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_from_sou… │ (None, 1, 1)      │          3 │ input_from_sourc… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_numeric       │ (None, 5)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_family_men… │ (None, 1)         │          0 │ embedding_family… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_suicidal_t… │ (None, 1)         │          0 │ embedding_suicid… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_dietary_ha… │ (None, 1)         │          0 │ embedding_dietar… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_dietary_ha… │ (None, 1)         │          0 │ embedding_dietar… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_dietary_ha… │ (None, 1)         │          0 │ embedding_dietar… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_gender_Fem… │ (None, 1)         │          0 │ embedding_gender… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_gender_Male │ (None, 1)         │          0 │ embedding_gender… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_sleep_dura… │ (None, 1)         │          0 │ embedding_sleep_… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_sleep_dura… │ (None, 1)         │          0 │ embedding_sleep_… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_sleep_dura… │ (None, 1)         │          0 │ embedding_sleep_… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_sleep_dura… │ (None, 1)         │          0 │ embedding_sleep_… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_from_sourc… │ (None, 1)         │          0 │ embedding_from_s… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_from_sourc… │ (None, 1)         │          0 │ embedding_from_s… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_embedd… │ (None, 18)        │          0 │ input_numeric[0]… │
# │ (Concatenate)       │                   │            │ flatten_family_m… │
# │                     │                   │            │ flatten_suicidal… │
# │                     │                   │            │ flatten_dietary_… │
# │                     │                   │            │ flatten_dietary_… │
# │                     │                   │            │ flatten_dietary_… │
# │                     │                   │            │ flatten_gender_F… │
# │                     │                   │            │ flatten_gender_M… │
# │                     │                   │            │ flatten_sleep_du… │
# │                     │                   │            │ flatten_sleep_du… │
# │                     │                   │            │ flatten_sleep_du… │
# │                     │                   │            │ flatten_sleep_du… │
# │                     │                   │            │ flatten_from_sou… │
# │                     │                   │            │ flatten_from_sou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      2,432 │ concatenate_embe… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batchnorm_1         │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ batchnorm_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batchnorm_2         │ (None, 64)        │        256 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ batchnorm_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 1)         │         65 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,560 (45.16 KB)
#  Trainable params: 11,176 (43.66 KB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.5792 - loss: 0.8044 - precision: 0.2453 - recall: 0.7497 - val_accuracy: 0.8101 - val_loss: 0.7034 - val_precision: 0.5000 - val_recall: 0.8971
# Epoch 2/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7024 - loss: 0.5818 - precision: 0.3600 - recall: 0.9537 - val_accuracy: 0.8743 - val_loss: 0.6309 - val_precision: 0.6237 - val_recall: 0.8529
# Epoch 3/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7247 - loss: 0.5627 - precision: 0.3654 - recall: 0.9289 - val_accuracy: 0.8994 - val_loss: 0.5852 - val_precision: 0.7105 - val_recall: 0.7941
# Epoch 4/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7921 - loss: 0.4994 - precision: 0.4583 - recall: 0.9431 - val_accuracy: 0.9078 - val_loss: 0.5348 - val_precision: 0.7612 - val_recall: 0.7500
# Epoch 5/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8173 - loss: 0.4529 - precision: 0.4953 - recall: 0.9518 - val_accuracy: 0.9218 - val_loss: 0.4888 - val_precision: 0.8448 - val_recall: 0.7206
# Epoch 6/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8349 - loss: 0.4132 - precision: 0.5011 - recall: 0.9449 - val_accuracy: 0.9330 - val_loss: 0.4466 - val_precision: 0.9074 - val_recall: 0.7206
# Epoch 7/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8556 - loss: 0.4083 - precision: 0.5698 - recall: 0.9281 - val_accuracy: 0.9413 - val_loss: 0.3991 - val_precision: 0.9273 - val_recall: 0.7500
# Epoch 8/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8486 - loss: 0.3980 - precision: 0.5241 - recall: 0.9010 - val_accuracy: 0.9413 - val_loss: 0.3617 - val_precision: 0.9796 - val_recall: 0.7059
# Epoch 9/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8674 - loss: 0.3235 - precision: 0.5659 - recall: 0.9611 - val_accuracy: 0.9385 - val_loss: 0.3235 - val_precision: 0.9792 - val_recall: 0.6912
# Epoch 10/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8934 - loss: 0.3225 - precision: 0.6598 - recall: 0.9196 - val_accuracy: 0.9553 - val_loss: 0.2916 - val_precision: 0.9815 - val_recall: 0.7794
# Epoch 11/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9137 - loss: 0.2715 - precision: 0.6819 - recall: 0.9717 - val_accuracy: 0.9469 - val_loss: 0.2702 - val_precision: 0.9804 - val_recall: 0.7353
# Epoch 12/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9272 - loss: 0.2634 - precision: 0.7393 - recall: 0.9554 - val_accuracy: 0.9553 - val_loss: 0.2456 - val_precision: 0.9815 - val_recall: 0.7794
# Epoch 13/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9352 - loss: 0.2327 - precision: 0.7254 - recall: 0.9962 - val_accuracy: 0.9609 - val_loss: 0.2253 - val_precision: 1.0000 - val_recall: 0.7941
# Epoch 14/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9378 - loss: 0.2511 - precision: 0.7548 - recall: 0.9662 - val_accuracy: 0.9804 - val_loss: 0.2005 - val_precision: 0.9841 - val_recall: 0.9118
# Epoch 15/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9482 - loss: 0.2141 - precision: 0.7896 - recall: 0.9500 - val_accuracy: 0.9777 - val_loss: 0.1848 - val_precision: 0.9545 - val_recall: 0.9265
# Epoch 16/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9422 - loss: 0.2184 - precision: 0.7604 - recall: 0.9536 - val_accuracy: 0.9888 - val_loss: 0.1704 - val_precision: 1.0000 - val_recall: 0.9412
# Epoch 17/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9600 - loss: 0.1823 - precision: 0.8289 - recall: 0.9793 - val_accuracy: 0.9832 - val_loss: 0.1628 - val_precision: 1.0000 - val_recall: 0.9118
# Epoch 18/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9741 - loss: 0.1682 - precision: 0.8810 - recall: 0.9818 - val_accuracy: 0.9860 - val_loss: 0.1478 - val_precision: 0.9846 - val_recall: 0.9412
# Epoch 19/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9597 - loss: 0.1599 - precision: 0.8128 - recall: 0.9970 - val_accuracy: 0.9916 - val_loss: 0.1370 - val_precision: 1.0000 - val_recall: 0.9559
# Epoch 20/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9689 - loss: 0.1682 - precision: 0.8770 - recall: 0.9598 - val_accuracy: 0.9888 - val_loss: 0.1304 - val_precision: 0.9706 - val_recall: 0.9706
# Epoch 21/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9756 - loss: 0.1542 - precision: 0.8901 - recall: 0.9705 - val_accuracy: 0.9860 - val_loss: 0.1281 - val_precision: 0.9437 - val_recall: 0.9853
# Epoch 22/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9704 - loss: 0.1676 - precision: 0.8942 - recall: 0.9555 - val_accuracy: 0.9916 - val_loss: 0.1225 - val_precision: 0.9710 - val_recall: 0.9853
# Epoch 23/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9696 - loss: 0.1534 - precision: 0.8520 - recall: 0.9862 - val_accuracy: 0.9916 - val_loss: 0.1158 - val_precision: 0.9851 - val_recall: 0.9706
# Epoch 24/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9671 - loss: 0.1424 - precision: 0.8523 - recall: 0.9784 - val_accuracy: 0.9832 - val_loss: 0.1192 - val_precision: 0.9189 - val_recall: 1.0000
# Epoch 25/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9684 - loss: 0.1323 - precision: 0.8516 - recall: 0.9887 - val_accuracy: 0.9832 - val_loss: 0.1111 - val_precision: 0.9429 - val_recall: 0.9706
# Epoch 26/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9734 - loss: 0.1313 - precision: 0.8727 - recall: 0.9898 - val_accuracy: 0.9888 - val_loss: 0.1092 - val_precision: 0.9444 - val_recall: 1.0000
# Epoch 27/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9776 - loss: 0.1398 - precision: 0.9061 - recall: 0.9901 - val_accuracy: 0.9832 - val_loss: 0.1068 - val_precision: 0.9429 - val_recall: 0.9706
# Epoch 28/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9727 - loss: 0.1347 - precision: 0.8655 - recall: 0.9930 - val_accuracy: 0.9832 - val_loss: 0.1077 - val_precision: 0.9429 - val_recall: 0.9706
# Epoch 29/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.1099 - precision: 0.9271 - recall: 0.9938 - val_accuracy: 0.9916 - val_loss: 0.0996 - val_precision: 0.9577 - val_recall: 1.0000
# Epoch 30/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9762 - loss: 0.1307 - precision: 0.8919 - recall: 0.9738 - val_accuracy: 0.9888 - val_loss: 0.1046 - val_precision: 0.9444 - val_recall: 1.0000
# Epoch 31/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9746 - loss: 0.1251 - precision: 0.8850 - recall: 0.9834 - val_accuracy: 0.9860 - val_loss: 0.1031 - val_precision: 0.9437 - val_recall: 0.9853
# Epoch 32/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9753 - loss: 0.1275 - precision: 0.8881 - recall: 0.9841 - val_accuracy: 0.9860 - val_loss: 0.0977 - val_precision: 0.9565 - val_recall: 0.9706
# Epoch 33/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.1102 - precision: 0.9294 - recall: 0.9918 - val_accuracy: 0.9832 - val_loss: 0.0982 - val_precision: 0.9429 - val_recall: 0.9706
# Epoch 34/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9836 - loss: 0.1161 - precision: 0.9294 - recall: 0.9817 - val_accuracy: 0.9804 - val_loss: 0.1130 - val_precision: 0.9178 - val_recall: 0.9853
# Epoch 35/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9778 - loss: 0.1195 - precision: 0.8983 - recall: 0.9813 - val_accuracy: 0.9832 - val_loss: 0.0947 - val_precision: 0.9429 - val_recall: 0.9706
# Epoch 36/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9889 - loss: 0.1018 - precision: 0.9482 - recall: 0.9940 - val_accuracy: 0.9832 - val_loss: 0.0942 - val_precision: 0.9429 - val_recall: 0.9706
# Epoch 37/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9841 - loss: 0.1067 - precision: 0.9465 - recall: 0.9634 - val_accuracy: 0.9860 - val_loss: 0.0876 - val_precision: 0.9437 - val_recall: 0.9853
# Epoch 38/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9881 - loss: 0.0946 - precision: 0.9471 - recall: 0.9869 - val_accuracy: 0.9860 - val_loss: 0.0970 - val_precision: 0.9315 - val_recall: 1.0000
# Epoch 39/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9900 - loss: 0.1021 - precision: 0.9535 - recall: 0.9964 - val_accuracy: 0.9832 - val_loss: 0.0919 - val_precision: 0.9306 - val_recall: 0.9853
# Epoch 40/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9822 - loss: 0.1069 - precision: 0.9089 - recall: 0.9802 - val_accuracy: 0.9804 - val_loss: 0.1101 - val_precision: 0.9067 - val_recall: 1.0000
# Epoch 41/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9753 - loss: 0.1114 - precision: 0.8865 - recall: 0.9915 - val_accuracy: 0.9777 - val_loss: 0.1167 - val_precision: 0.8947 - val_recall: 1.0000
# Epoch 42/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9772 - loss: 0.1047 - precision: 0.8809 - recall: 0.9978 - val_accuracy: 0.9860 - val_loss: 0.0876 - val_precision: 0.9437 - val_recall: 0.9853
# Epoch 43/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9824 - loss: 0.0991 - precision: 0.9207 - recall: 0.9778 - val_accuracy: 0.9804 - val_loss: 0.0882 - val_precision: 0.9296 - val_recall: 0.9706
# Epoch 44/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9758 - loss: 0.0984 - precision: 0.8830 - recall: 0.9921 - val_accuracy: 0.9832 - val_loss: 0.0948 - val_precision: 0.9306 - val_recall: 0.9853
# Epoch 45/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9872 - loss: 0.0964 - precision: 0.9499 - recall: 0.9820 - val_accuracy: 0.9804 - val_loss: 0.0982 - val_precision: 0.9296 - val_recall: 0.9706
# Epoch 46/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0880 - precision: 0.9519 - recall: 0.9886 - val_accuracy: 0.9832 - val_loss: 0.1013 - val_precision: 0.9189 - val_recall: 1.0000
# Epoch 47/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9868 - loss: 0.0962 - precision: 0.9378 - recall: 0.9940 - val_accuracy: 0.9860 - val_loss: 0.0824 - val_precision: 0.9565 - val_recall: 0.9706
# Epoch 48/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0939 - precision: 0.9434 - recall: 0.9795 - val_accuracy: 0.9804 - val_loss: 0.0900 - val_precision: 0.9178 - val_recall: 0.9853
# Epoch 49/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9888 - loss: 0.0790 - precision: 0.9430 - recall: 0.9987 - val_accuracy: 0.9860 - val_loss: 0.0819 - val_precision: 0.9437 - val_recall: 0.9853
# Epoch 50/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9846 - loss: 0.1010 - precision: 0.9231 - recall: 0.9849 - val_accuracy: 0.9832 - val_loss: 0.0906 - val_precision: 0.9306 - val_recall: 0.9853
# Epoch 51/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9810 - loss: 0.0890 - precision: 0.9055 - recall: 0.9971 - val_accuracy: 0.9860 - val_loss: 0.0793 - val_precision: 0.9437 - val_recall: 0.9853
# Epoch 52/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9904 - loss: 0.0844 - precision: 0.9552 - recall: 0.9934 - val_accuracy: 0.9804 - val_loss: 0.0904 - val_precision: 0.9178 - val_recall: 0.9853
# Epoch 53/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9803 - loss: 0.1182 - precision: 0.9371 - recall: 0.9594 - val_accuracy: 0.9888 - val_loss: 0.0761 - val_precision: 0.9706 - val_recall: 0.9706
# Epoch 54/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0810 - precision: 0.9430 - recall: 0.9896 - val_accuracy: 0.9832 - val_loss: 0.0817 - val_precision: 0.9306 - val_recall: 0.9853
# Epoch 55/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9917 - loss: 0.0737 - precision: 0.9573 - recall: 1.0000 - val_accuracy: 0.9832 - val_loss: 0.0851 - val_precision: 0.9306 - val_recall: 0.9853
# Epoch 56/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9867 - loss: 0.0839 - precision: 0.9351 - recall: 0.9883 - val_accuracy: 0.9832 - val_loss: 0.0937 - val_precision: 0.9189 - val_recall: 1.0000
# Epoch 57/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0892 - precision: 0.9261 - recall: 0.9873 - val_accuracy: 0.9860 - val_loss: 0.0848 - val_precision: 0.9315 - val_recall: 1.0000
# Epoch 58/1000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.0910 - precision: 0.9322 - recall: 0.9972 - val_accuracy: 0.9832 - val_loss: 0.0862 - val_precision: 0.9189 - val_recall: 1.0000

# %%
y_pred_proba_mlp = model_mlp.predict(X_test_list)
y_pred_mlp = (y_pred_proba_mlp > 0.5).astype(int)
# print(y_pred_mlp)
mlp_result = ['MLP (Keras, ES)'] + getResult(y_test_mlp, y_pred_mlp)
# Out:
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.9972051425377306
# Precision: 0.9905956112852664
# Recall: 0.9937106918238994
# F1 score: 0.9921507064364207
# Confusion matrix:
# [[1468    3]
#  [   2  316]]

# %% [markdown]
# # Summary

# %%
all_results_data = [
    lr_result,
    nb_result,
    dstree_result,
    rf_result,
    xgb_result,     # Kết quả XGBoost đã cân bằng
    mlp_result,              # Kết quả MLP với Early Stopping
]

final_results = pd.DataFrame(data=all_results_data,
                             columns=['Model','Accuracy','Precision','Recall','F1'])

print("\n--- Final Comparison Results (Updated) ---")
display(final_results)
# Out:
# --- Final Comparison Results (Updated) ---
#                  Model  Accuracy  Precision    Recall        F1
# 0  Logistic Regression  0.977836   0.892405  1.000000  0.943144
# 1          Naive Bayes  0.818774   0.506173  0.581560  0.541254
# 2        Decision Tree  0.912647   0.789062  0.716312  0.750929
# 3        Random Forest  0.911343   0.892473  0.588652  0.709402
# 4              XGBoost  0.962190   0.894366  0.900709  0.897527
# 5      MLP (Keras, ES)  0.777053   0.083333  0.021277  0.033898
